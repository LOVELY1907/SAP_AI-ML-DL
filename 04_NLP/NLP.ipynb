# %% [markdown]
# <a href="https://colab.research.google.com/github/LOVELY1907/SAP_AI-ML-DL/blob/main/04_NLP/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = "I AM A MACHINE LEARNING EXPERT"
print(sentence.lower())
# Out:
# i am a machine learning expert

# %%
#we need to import regular expression
import re
#A function which can remove the HTML Tags
def removal(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
cleaned_text = removal(text_with_html)
print(f"Original text: {text_with_html} ")
print(f"Cleaned text: {cleaned_text}")
# Out:
# Original text: <html><body><h1>Hello</h1><p>This is a <b>test</b>.</p></body></html>
# Cleaned text: HelloThis is a test.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import string
string.punctuation
exclude = string.punctuation

def remove_punctuation(text):
    for char in exclude:
        text = text.replace(char,'')
    return text

# %%
text_without_punctuation = remove_punctuation(cleaned_text)
print(f"Text without HTML tags: {cleaned_text}")
print(f"Text without punctuation: {text_without_punctuation}")
# Out:
# Text without HTML tags: HelloThis is a test.
# Text without punctuation: HelloThis is a test

# %%
import re
def remove(text):
  patterns = re.compile(patterns)
  return patterns.sub(r'',text)

# %%
from textblob import TextBlob

def correct(text):
  textblob = TextBlob(text)
  return textblob.correct().string

# %%
misspelled_text = "This is a sampll text with an eror."
corrected_text = correct(misspelled_text)
print(f"Original text: {misspelled_text}")
print(f"Corrected text: {corrected_text}")
# Out:
# Original text: This is a sampll text with an eror.
# Corrected text: His is a sample text with an error.

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

def generate_tokens(text):
  return word_tokenize(text) #for generate the words tokens

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
generate_tokens("i am a boy")
# Out:
# ['i', 'am', 'a', 'boy']

# %%
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()
def stemm(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
stemm('i am lovely')
# Out:
# 'i am love'

# %%
stemm('eating')
# Out:
# 'eat'

# %%
generate_tokens('my name is lovely')
# Out:
# ['my', 'name', 'is', 'lovely']

# %%
correct('i havs a packet of chips')
# Out:
# 'i have a packet of chips'
